# %% [markdown]
# # NBA Pro-Lite Starter Notebook
# Run all cells top to bottom.

# %%
# !pip install pandas numpy requests pyyaml scikit-learn lightgbm xgboost

# %%
import os, yaml, pandas as pd
RAPIDAPI_KEY = os.getenv('RAPIDAPI_KEY')
ODDS_API_KEY = os.getenv('ODDS_API_KEY')
print('RAPIDAPI_KEY set:', bool(RAPIDAPI_KEY))
print('ODDS_API_KEY set:', bool(ODDS_API_KEY))
cfg = yaml.safe_load(open('config/config.yaml'))
cfg

# %%
print('Ingest placeholder ran.')
